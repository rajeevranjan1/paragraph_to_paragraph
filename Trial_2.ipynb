# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    SL No.        Date Asset      Equipment / Fac. System                 Tag  \
# 0     NaN         NaN   NaN                          NaN                 NaN
# 1     1.0  12-03-2019  USAN  Oil Separation       System    USN_5LI200304.PV
# 2     NaN         NaN   NaN                          NaN                 NaN
# 3     2.0  12-03-2019  USAN  Oil Separation       System  USN_5PIC200302A.PV
# 4     NaN         NaN   NaN                          NaN                 NaN
#
#                                       Excursion Name  \
# 0                                                NaN
# 1  !st stage separator Train B oil Level went upt...
# 2                                                NaN
# 3  !st stage separator Train B Pressure went high...
# 4                                                NaN
#
#    Excursion Count (No. of times same excursion occurred)  \
# 0                                                NaN
# 1                                                2.0
# ...

# %%
df.shape
# Out:
# (90, 9)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     SL No.        Date    Asset  \
# 1      1.0  12-03-2019     USAN
# 3      2.0  12-03-2019     USAN
# 7      4.0  20-12-2020   USAN 1
# 9      5.0  03-01-2020   USAN 2
# 11     6.0  24-01-2020   USAN 3
# 13     7.0  27-01-2020   USAN 4
# 15     8.0  11-02-2020   USAN 5
# 17     9.0  25-02-2020   USAN 6
# 19    10.0  19-03-2020   USAN 7
# 21    11.0  26-03-2020   USAN 8
# 23    12.0  27-03-2020   USAN 9
# 25    13.0  27-03-2020  USAN 10
# 27    14.0  22-04-2020  USAN 11
# 29    15.0  27-04-2020  USAN 12
# 31    16.0  13-05-2020  USAN 13
# 33    17.0  27-05-2020  USAN 14
# 35    18.0  27-05-2020  USAN 15
# 37    19.0  12-06-2020  USAN 16
# 39    20.0  12-06-2020  USAN 16
# 41    21.0  19-06-2020  USAN 16
# 43    22.0  25-06-2020  USAN 17
# 45    23.0  03-07-2020  USAN 18
# 47    23.0  14-07-2020  USAN 19
# 49    24.0  27-07-2020  USAN 20
# 51    25.0  28-07-2020  USAN 21
# 53    26.0  07-08-2020  USAN 22
# 55    27.0  13-08-2020  USAN 23
# 57    28.0  25-08-2020  USAN 24
# ...

# %%
df['Comments'][1]
# Out:
# "Excursion details:-1st Stage Separator train B oil level went more than high high limit 2 to 3 time i.e. more than 89.5% after startup.\n\nAnalysis:- Level control valve was 100% open  working as per level control philosphy  but more flow can be achieved through bypass\n\nRecommendation:- If feasible line up  34' Bypass  in line whenevr level build up suddenly in any of two 1st stage  separator train A or B "

# %%
df['Comments'].str.split('\nRecommendation')[1]
# Out:
# ['Excursion details:-1st Stage Separator train B oil level went more than high high limit 2 to 3 time i.e. more than 89.5% after startup.\n\nAnalysis:- Level control valve was 100% open  working as per level control philosphy  but more flow can be achieved through bypass\n',
#  ":- If feasible line up  34' Bypass  in line whenevr level build up suddenly in any of two 1st stage  separator train A or B "]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     SL No.        Date    Asset  \
# 0      1.0  12-03-2019     USAN
# 1      2.0  12-03-2019     USAN
# 2      4.0  20-12-2020   USAN 1
# 3      5.0  03-01-2020   USAN 2
# 4      6.0  24-01-2020   USAN 3
# 5      7.0  27-01-2020   USAN 4
# 6      8.0  11-02-2020   USAN 5
# 7      9.0  25-02-2020   USAN 6
# 8     10.0  19-03-2020   USAN 7
# 9     11.0  26-03-2020   USAN 8
# 10    12.0  27-03-2020   USAN 9
# 11    13.0  27-03-2020  USAN 10
# 12    14.0  22-04-2020  USAN 11
# 13    15.0  27-04-2020  USAN 12
# 14    16.0  13-05-2020  USAN 13
# 15    17.0  27-05-2020  USAN 14
# 16    18.0  27-05-2020  USAN 15
# 17    19.0  12-06-2020  USAN 16
# 18    20.0  12-06-2020  USAN 16
# 19    21.0  19-06-2020  USAN 16
# 20    22.0  25-06-2020  USAN 17
# 21    23.0  03-07-2020  USAN 18
# 22    23.0  14-07-2020  USAN 19
# 23    24.0  27-07-2020  USAN 20
# 24    25.0  28-07-2020  USAN 21
# 25    26.0  07-08-2020  USAN 22
# 26    27.0  13-08-2020  USAN 23
# 27    28.0  25-08-2020  USAN 24
# ...

# %%
split_values=df['Comments'].str.split('\nRecommendation')

# %%
df['inputs']=df['Comments'].apply(lambda x:x.split('\nRecommendation')[0])

# %%
df.columns
# Out:
# Index(['SL No.', 'Date', 'Asset', 'Equipment / Fac. System', 'Tag',
#        'Excursion Name',
#        'Excursion Count (No. of times same excursion occurred)',
#        'Follow-up\r\n\r\n(Notification Req'd or Notification not Req'd)',
#        'Comments', 'outputs', 'inputs'],
#       dtype='object')

# %%
new_df=df[['inputs','outputs']]

# %%
new_df['inputs']=new_df['inputs'].str.replace(':',' ')
# Out:
# C:\Users\Rajeev\AppData\Local\Temp\ipykernel_25944\919641970.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['inputs']=new_df['inputs'].str.replace(':',' ')

# %%
new_df['outputs']=new_df['outputs'].str.replace(':',' ')
# Out:
# C:\Users\Rajeev\AppData\Local\Temp\ipykernel_25944\1160890821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['outputs']=new_df['outputs'].str.replace(':',' ')

# %%
new_df
# Out:
#                                                inputs  \
# 0   Excursion details -1st Stage Separator train B...
# 1   Excursion details -1st stage separator pressur...
# 2   Excursion details -HP1 Compreesor Suction scru...
# 3   Excursion details -TEG train B reboiler reflux...
# 4   Excursion details -ES3008A Lean glycol cold co...
# 5   Excursion details -ES2001B Crude Oil heater DP...
# 6   Excursion details -TEG Gas Coalescer Filter VF...
# 7   Excursion details -1st Stage Separator B Press...
# 8   Excursion details -MP compressor B KA 3104B  D...
# 9   Excursion details -Fine Filters VF 5102C DP is...
# 10  Excursion details -Fine filters package outlet...
# 11  Excursion details -TEG B Contactor outlet and ...
# 12  Excursion details - Fuel gas Filter VF 7001A/B...
# 13  Excursion details - Degassing Drum level has b...
# 14  Excursion details First Stage Separator VZ2001...
# 15  Excursion details - USN_4AI210151B/A Oil in wa...
# ...

# %%
new_df.to_csv('input_output.csv',index=False)

# %%
new_df
# Out:
#                                                inputs  \
# 0   Excursion details -1st Stage Separator train B...
# 1   Excursion details -1st stage separator pressur...
# 2   Excursion details -HP1 Compreesor Suction scru...
# 3   Excursion details -TEG train B reboiler reflux...
# 4   Excursion details -ES3008A Lean glycol cold co...
# 5   Excursion details -ES2001B Crude Oil heater DP...
# 6   Excursion details -TEG Gas Coalescer Filter VF...
# 7   Excursion details -1st Stage Separator B Press...
# 8   Excursion details -MP compressor B KA 3104B  D...
# 9   Excursion details -Fine Filters VF 5102C DP is...
# 10  Excursion details -Fine filters package outlet...
# 11  Excursion details -TEG B Contactor outlet and ...
# 12  Excursion details - Fuel gas Filter VF 7001A/B...
# 13  Excursion details - Degassing Drum level has b...
# 14  Excursion details First Stage Separator VZ2001...
# 15  Excursion details - USN_4AI210151B/A Oil in wa...
# ...
